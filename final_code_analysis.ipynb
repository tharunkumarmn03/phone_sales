# %%
# import python libraries

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import csv file

df=pd.read_excel(r"C:\Users\tharu\OneDrive\Desktop\data sets\smartphones_cleaned_v6.xlsx")

# %%
df.head(5)
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 0           False      snapdragon        8.0              3.2  ...
# 1           False      snapdragon        8.0              2.2  ...
# 2           False          exynos        8.0              2.4  ...
# 3           False      snapdragon        8.0              2.2  ...
# 4           False       dimensity        8.0              2.6  ...
#
#    screen_size  refresh_rate  num_rear_cameras  num_front_cameras       os  \
# ...

# %%
# finding the rows and coloumns

df.shape
# Out:
# (980, 25)

# %%
 list(df.columns)
# Out:
# ['brand_name',
#  'model',
#  'price',
#  'rating',
#  'has_5g',
#  'has_nfc',
#  'has_ir_blaster',
#  'processor_brand',
#  'num_cores',
#  'processor_speed',
#  'battery_capacity',
#  'fast_charging_available',
#  'fast_charging',
#  'ram_capacity',
#  'internal_memory',
#  'screen_size',
#  'refresh_rate',
#  'num_rear_cameras',
#  'num_front_cameras',
#  'os',
#  'primary_camera_rear',
#  'primary_camera_front',
#  'extended_memory_available',
#  'resolution_width',
#  'resolution_height']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  battery_capacity           969 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              769 non-null    float64
# ...

# %%
#check for null values

df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       101
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               20
# num_cores                      6
# processor_speed               42
# battery_capacity              11
# fast_charging_available        0
# fast_charging                211
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# num_rear_cameras               0
# num_front_cameras              4
# os                            14
# primary_camera_rear            0
# primary_camera_front           5
# extended_memory_available      0
# resolution_width               0
# resolution_height              0
# dtype: int64

# %%
#filling null values 

df['rating']=df['rating'].fillna(0)

# %%
df['rating'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Adding 0 to null_values for the rating columns because the column is in numeric value and 0 will be treated as no review is given to the phones.

# %%
df['processor_speed'].isnull().sum()
# Out:
# 42

# %%
df['processor_speed']=df['processor_speed'].fillna('0')

# %%
df['processor_speed']=df['processor_speed'].replace('Na','')

# %%
df['processor_speed'].isnull().sum()
# Out:
# 0

# %%
df['fast_charging'].isnull().sum()
# Out:
# 211

# %%
df['fast_charging']=df['fast_charging'].fillna('0')

# %%
# drop null values

df=df.dropna()

# %%
df.isnull().sum()
# Out:
# brand_name                   0
# model                        0
# price                        0
# rating                       0
# has_5g                       0
# has_nfc                      0
# has_ir_blaster               0
# processor_brand              0
# num_cores                    0
# processor_speed              0
# battery_capacity             0
# fast_charging_available      0
# fast_charging                0
# ram_capacity                 0
# internal_memory              0
# screen_size                  0
# refresh_rate                 0
# num_rear_cameras             0
# num_front_cameras            0
# os                           0
# primary_camera_rear          0
# primary_camera_front         0
# extended_memory_available    0
# resolution_width             0
# resolution_height            0
# dtype: int64

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)

df.describe()
# Out:
#                price      rating   num_cores  battery_capacity  \
# count     927.000000  927.000000  927.000000        927.000000
# mean    30964.143474   70.912621    7.816613       4828.480043
# std     38285.655726   24.130090    0.758554        998.352881
# min      3499.000000    0.000000    4.000000       1821.000000
# 25%     12999.000000   71.000000    8.000000       4500.000000
# 50%     19990.000000   79.000000    8.000000       5000.000000
# 75%     33824.500000   84.000000    8.000000       5000.000000
# max    650000.000000   89.000000    8.000000      22000.000000
#
#        fast_charging_available  ram_capacity  internal_memory  screen_size  \
# count               927.000000    927.000000       927.000000   927.000000
# mean                  0.869471      6.584682       139.918015     6.543819
# std                   0.337066      2.710491       104.578439     0.309170
# min                   0.000000      1.000000         8.000000     3.540000
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
list(df.columns)
# Out:
# ['brand_name',
#  'model',
#  'price',
#  'rating',
#  'has_5g',
#  'has_nfc',
#  'has_ir_blaster',
#  'processor_brand',
#  'num_cores',
#  'processor_speed',
#  'battery_capacity',
#  'fast_charging_available',
#  'fast_charging',
#  'ram_capacity',
#  'internal_memory',
#  'screen_size',
#  'refresh_rate',
#  'num_rear_cameras',
#  'num_front_cameras',
#  'os',
#  'primary_camera_rear',
#  'primary_camera_front',
#  'extended_memory_available',
#  'resolution_width',
#  'resolution_height']

# %%
# plotting a bar chart for brand_name and it's count

dff=df['brand_name'].value_counts().head(15)

dfff=dff.plot(kind ='bar',color='green')
for bars in dfff.containers:
    dfff.bar_label(bars)
sns.set(rc={'figure.figsize':(15,5)})
plt.title('List of brand')
# Out:
# Text(0.5, 1.0, 'List of brand')

# %% [markdown]
#        This is the top 15 highest sales acconding to the brand. Xiaomi is having a highest sales in the data

# %%
# plotting a bar chart for model vs price

phone_price=df[['model','price']].sort_values(by='price',ascending=False).head(10)

dff=sns.barplot(x='model',y='price',data=phone_price)
sns.set(rc={'figure.figsize':(10,5)})
plt.xticks(rotation=90)
plt.title ('Top_price')
for bars in dff.containers:
    dff.bar_label(bars)

# %% [markdown]
#   This is the top 10 highest phone price in the data. Vertu signature Touch is the higest phone price.

# %%
# plotting a bar chart for model vs price

phone_price=df[['model','price']].sort_values(by='price').head(12)

dff=sns.barplot(x='model',y='price',data=phone_price)
sns.set(rc={'figure.figsize':(10,5)})
plt.xticks(rotation=90)
plt.title ('Cheapest_phone')
for bars in dff.containers:
    dff.bar_label(bars)

# %% [markdown]
# This is the top 10 cheapest phone price in the data. Realme C2s is the cheapest phone price.

# %%
# plotting a bar chart for brand_name vs rating

brand_rating=df.groupby(['brand_name'],as_index=False)['rating'].sum().sort_values(by='rating',ascending=False).head(15)

sns.barplot(x='brand_name',y='rating',data=brand_rating)
sns.set(rc={'figure.figsize':(15,5)})
plt.title ('Company_rating')
# Out:
# Text(0.5, 1.0, 'Company_rating')

# %% [markdown]
# From the above graph we can see that rating according to Brand given by the customer.Top rating according to barnds are Xiaomi , samsung ,vivo,  realme and oppo

# %%
# plotting a bar chart for has_5g and it's count

dff=sns.countplot(x='has_5g', data =df)
sns.set(rc={'figure.figsize':(5,5)})
for bars in dff.containers:
    dff.bar_label(bars)

# %% [markdown]
# From the above bar graph we can see that more 5g mobile_phones are used.

# %%
# plotting a bar chart for os and it's count

dff=sns.countplot(x='os', data=df)
for bars in dff.containers :
    dff.bar_label(bars)
sns.set(rc={'figure.figsize':(10,5)})

# %% [markdown]
# From the above graphs Android OS is uesd in phone compared to others.

# %%
# plotting a pie chart for fast_charging_available and it's percentage

dff=df['fast_charging_available'].value_counts()

dff.plot(kind='pie',autopct='%1.f%%')
sns.set(rc={'figure.figsize':(15,5)})

# %% [markdown]
# From the graphs you can see 87% fast_charging_avilable in the phones.

# %%
# plotting a bar chart for brand_name vs rating

dff=df.groupby(['num_cores'],as_index=False)['processor_brand'].count()

dada=sns.barplot(x='num_cores',y='processor_brand', data=dff , hue='num_cores')
for bars in dada.containers:
    dada.bar_label(bars)
sns.set(rc={'figure.figsize':(8,5)})

# %% [markdown]
# From the above we can see that 8GB core is having more in the processer brand.

# %%
# plotting a bar chart for processor_brand and it's count

dff=sns.histplot(x='processor_brand',data =df )
sns.set(rc={'figure.figsize':(15,5)}) 
for bars in dff.containers :
    dff.bar_label(bars)

# %% [markdown]
# From the above graphs you see the Snapdragon processor is used more in the phone

# %%
# plotting a bar chart for processor_brand vs os

dff=sns.countplot(x='processor_brand', data =df ,hue='os')
sns.set(rc={'figure.figsize':(15,5)}) 
for bars in dff.containers:
    dff.bar_label(bars)

# %% [markdown]
#  From the above graphs we can see more snapdragon processor is used in phone by comparing with the os.

# %%
# plotting a hist chart for processor_speed and it's count

sns.histplot(x='processor_speed', data=df, bins=10)
sns.set(rc={'figure.figsize':(10,5)})

# %% [markdown]
# From the above graphs we can see that from the range of 1.5 to 2.5 have the higest count of processor_speed in the mobiles.

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# 8.0    870
# 6.0     29
# 4.0     28
# Name: count, dtype: int64

# %%
# plotting a bar chart for processor_brand vs num_cores

dfff=sns.countplot(x='processor_brand',data=df,hue='num_cores')
for bars in dfff.containers:
    dfff.bar_label(bars)
sns.set(rc={'figure.figsize':(15,5)})

# %% [markdown]
# we can see that comparition of the core with the processor_brand.8GB core having a more numbers.

# %%
# plotting a bar chart for refresh_rate upon num_cores

sns.countplot(x='refresh_rate',data=df, hue ='num_cores')
# Out:
# <Axes: xlabel='refresh_rate', ylabel='count'>

# %% [markdown]
# From the graphs we can see that 8G ram and 120Hz refreshing_rate  having more count of phones.

# %%
df['brand_name'].value_counts().head(12)
# Out:
# brand_name
# xiaomi      133
# samsung     119
# vivo        111
# realme       97
# oppo         84
# motorola     52
# oneplus      42
# poco         41
# tecno        32
# iqoo         32
# apple        31
# infinix      29
# Name: count, dtype: int64

# %%
# plotting a bar chart for brand_name vs has_5g vs rating

dff=df.groupby(['brand_name','has_5g'],as_index=False)['rating'].count().sort_values(by='rating', ascending=False).head(10)

dataa=sns.barplot(x='brand_name',y='rating', data=dff,hue='has_5g')
for bars in dataa.containers:
    dataa.bar_label(bars)
sns.set(rc={'figure.figsize':(15,10)})

# %% [markdown]
# From the above graphs we can see that Xiaomi is having a highest rating given by the customer for both 5G and non 5G phones.

# %%
pd.set_option('display.max_rows',None)

# %%
# plotting a bar chart for brand_name vs num_cores vs refresh_rate

dff=df.groupby('brand_name').value_counts(['num_cores','refresh_rate']).sort_values(ascending=False).head(20)

dfff=dff.plot(kind='barh')
for bars in dfff.containers:
    dfff.bar_label(bars)
plt.xticks(rotation=90)
sns.set(rc={'figure.figsize':(15,15)})

# %% [markdown]
# From the above graph we can see that Xiaomi is having more count in all the num_cores and refresh_rate.

# %% [markdown]
# # Conclusion

# %% [markdown]
#  By reviwing the all the data and the visualization we can see that Xiaomi brand is having more sales with the features sucha as
#  processor_speed,num_cores,refresh_rate, rating ,price etc. And aslo more sales in both 5G and non 5g set of phones.

# %% [markdown]
# Thank you
